# %% [markdown]
# <a href="https://colab.research.google.com/github/costadeb/introducao-programacao-computadores/blob/main/AULA_ONLINE_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <?xml version="1.0" encoding="UTF-8"?>
# <html>
#   <body>
#     <header></header>
#         <CENTER>
#           <img src="https://docentes.uvv.br/Content/img/logo-uvv.png" alt="UVV-LOGO" style = width="100px"; height="100px">
#         </CENTER>
#         <CENTER><b>Introdução à Programação de Computadores - PYTHON</b></CENTER>
#         <CENTER><b>Prof.: Alessanddro Bertolani Oliveira</b>
#         <CENTER><b>Aula Online 1</b></CENTER><br/>

# %% [markdown]
# # O que vamos estudar:
#
# $\longmapsto$ <b>Tópico 01</b> - RACIOCÍNIO LÓGICO.<br/><br/>
# $\longmapsto$ <b>Tópico 02</b> - ÁLGEBRA BOOLEANA.<br/><br/>
# $\longmapsto$ <b>Tópico 03</b> - LÓGICA PROPOSICIONAL.<br/><br/>

# %% [markdown]
# # Tópico 01 - RACIOCÍNIO LÓGICO:

# %% [markdown]
# ## Definição de Lógica:
#
# A Lógica é uma Ciência (Matemática) que tem por objetivo colocar ordem no pensamento através do exercício das propriedades de **Generalização, Encadeamento e Inferência**.

# %% [markdown]
# $\mapsto$ **Generalização (Todo – Partes)**
#
# <CENTER><b>Todo mamífero é um animal.
#
# Todo cavalo é um mamífero.
#
# Portanto, todo cavalo é um animal.</b></CENTER><br/>

# %% [markdown]
# $\mapsto$ **Encadeamento**
#
# <CENTER><b>A gaveta está fechada.
#
# A caneta está dentro da gaveta.
#
# Precisamos primeiro abrir a gaveta para depois pegar a caneta.
# </b></CENTER><br/>

# %% [markdown]
# $\mapsto$ **Inferência**
#
# <CENTER><b>Anacleto é mais velho que Felisberto.
#
# Felisberto é mais velho que Marivaldo.
#
# Portanto, Anacleto é mais velho que Marivaldo.</b></CENTER><br/>

# %% [markdown]
# <CENTER><b> <b>Exemplo de aplicação formal prática das propriedades lógicas:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Linguagem Natural x Linguagem Artificial:

# %% [markdown]
# **Linguagem Natural:** é qualquer linguagem que os seres humanos aprendem em seu ambiente de vida e comunicação com outros seres humanos, como é o caso do português.

# %% [markdown]
# **Linguagem Artificial:** exprimem com correção e exatidão o pensamento e os resultados do conhecimento científico, de forma sintética: Padronizada e Estruturada.

# %% [markdown]
# ## Definição de Algoritmo:

# %% [markdown]
# É uma sequência de passos,
#
# *   **Ações (Aritméticas)** que devem ser executadas +
# *   **Decisões (Lógicas)** que devem ser tomadas
#
# com a determinação de atingir a um objetivo bem definido.

# %% [markdown]
# **Algoritmo Gráfico:** Fluxograma de Dados
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Algoritmo Textual:** Codificação Python

# %%
# ALGORITMO: ENTRADA (DADOS) + PROCESAMENTO (Unidade Lógica - Aritmética) + SAÍDA (INFORMAMAÇÃO)
A = float(input('Coeficiente A: '))
B = float(input('Coeficiente B: '))
C = float(input('Coeficiente C: '))
if A == 0 or (B == 0 and C == 0):
  print('Não é uma Equação do 2° Grau.')
else:
  delta = B ** 2 - 4 * A * C
  print(f'Valor de Delta: {delta: .2f}')
  if delta < 0:
    print('Não tem Raízes no conjunto dos números reais.')
  elif delta == 0:
    X1 = -B / (2 * A)
    print(f'Raiz X1 = X2 = {X1: .2f}')
  else:
    raizDelta = delta ** 0.5
    print(f'Valor da Raíz de Delta: {raizDelta: .2f}')
    X1 = (-B + raizDelta) / (2 * A)
    X2 = (-B - raizDelta) / (2 * A)
    print(f'Raiz X1 = {X1: .2f}')
    print(f'Raiz X2 = {X2: .2f}')
# Out:
# Coeficiente A: 1
# Coeficiente B: -1
# Coeficiente C: -2
# Valor de Delta:  9.00
# Valor da Raíz de Delta:  3.00
# Raiz X1 =  2.00
# Raiz X2 = -1.00

# %%
# ALGORITMO: ENTRADA (DADOS) + PROCESSAMENTO (ULA) + SAÍDA (Objetivo)
# ENTRADA: Dados do usuário
matricula = int(input('Matrícula: '))
nome = input('Nome: ')
massa = float(input('Massa: '))
altura = float(input('Altura: '))

# PROCESSAMENTO (ULA: Unidade Lógico - Aritméticos)
IMC = massa / (altura ** 2)

# SAÍDA (OBJETIVO(S))
print(f'IMC: {IMC: .1f}')
# Out:
# Matrícula: 20241234
# Nome: FULANO DE TAL
# Massa: 100.525
# Altura: 2.01
# IMC:  24.9

# %% [markdown]
# ## Conceito de Proposição:

# %% [markdown]
# Conjunto de palavras ou símbolos que exprimem um pensamento de sentido completo.
#
# São expressões a respeito das quais tem sentido dizer somente que são verdadeiras ou falsas.

# %% [markdown]
# Valor Lógico somente pode ser (**BIT: Binary digiT**)
#
# *   FALSO (False): 0
# *   VERDADEIRO (True): 1

# %% [markdown]
# EXEMPLOS X CONTRA-EXEMPLOS:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# A lógica matemática adota como regras fundamentais do pensamento os dois axiomas a seguir:
#
# I  –   Princípio da não contradição: uma proposição não pode ser verdadeira e falsa ao mesmo tempo.
#
# II –  Princípio do terceiro excluído: toda a proposição ou é verdadeira ou é falsa, isto é, verifica-se sempre um destes casos e nunca um terceiro.

# %% [markdown]
# ## Tipos de Proposição:

# %% [markdown]
# **Simples ou atômica:**
#
# é aquela proposição que não contem nenhuma outra proposição como parte integrante de si. São designadas por letras minúsculas.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Composta ou molecular:**
#
# é aquela formada pela combinação de duas ou mais proposições. São designadas por letras maiúsculas.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Notação Lógica Formal: Valor Lógico**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Operações Lógicas sobre Proposições:

# %% [markdown]
# $\longmapsto$ **Conectivos**: São palavras usadas para formar novas proposições a partir de outras. Os conectivos são operações matemáticas realizadas sobre as variáveis lógicas e as proposições. Assim, p. ex. nas seguintes proposições compostas, temos:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###Tabela-Verdade:
#
# é um dispositivo de modelagem que contém todas as combinações possíveis de valores que a variável lógica ou a proposição podem assumir. Segundo do Princípio do terceiro excluído, toda proposição simples p é verdadeira ou falsa.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Negação (NÃO):

# %%
login = False

# %%
not(login)
# Out:
# True

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Conjunção (E):

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
True and True
# Out:
# True

# %% [markdown]
# ### Disjunção (OU):

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
True or True
# Out:
# True

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Condicional (SE):

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Bicondicional (SE-E-SOMENTE-SE):

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Tópico 02 - ÁLGEBRA BOOLEANA:

# %% [markdown]
# ## Precedência entre os Conectivos:

# %% [markdown]
# Observe o resultado das seguinte operações aritmética:

# %%
# ULA
5 * 4 + 2
# Out:
# 22

# %%
5 * (4 + 2)
# Out:
# 30

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Resolução de expressões lógicas:

# %% [markdown]
# ### Expressões lógicas 1:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Expressões lógicas 2:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Expressões lógicas 3: CONTRADIÇÃO (todos falsos)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Expressões lógicas 4: TAUTOLOGIA (todos verdadeiros)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Conversão de Linguagem Natural para Artificial (Formal):

# %% [markdown]
# #### SENTENÇA LÓGICA 1:
#
# A: Lógica NÃO é difícil E Programação é Fácil.
#
# p: Lógica é difícil.
#
# q: Programação é Fácil.

# %% [markdown]
# RESPOSTA:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### SENTENÇA LÓGICA 2:
#
# A: NÃO é verdade que: lógica é difícil OU Programação NÃO é Fácil.
#
# p: Lógica é difícil.
#
# q: Programação é Fácil.

# %% [markdown]
# RESPOSTA:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### SENTENÇA LÓGICA 3:
#
# A: SE lógica é fácil ENTÃO Programação NÃO é difícil.
#
# p: Lógica é fácil.
#
# q: Programação é difícil.

# %% [markdown]
# RESPOSTA:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### SENTENÇA LÓGICA 4:
#
# A: SE lógica NÃO é difícil E Programação é fácil ENTÃO Python será uma moleza!!!.
#
# p: Lógica é difícil.
#
# q: Programação é fácil.
#
# r: Python será uma moleza!!!

# %% [markdown]
# RESPOSTA:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Software TRUTH TABLE:
#
# COMO RODAR ARQUIVO JAVA (.jar): Procurar pelo DIRETÓRIO do JAVA;
#
# NO: PROMPT DO DOS DO WINDOS (caso não funcione direto o arquivo)
#
# C:\>cd..
#
# C:\>cd Program Files (x86)\Java\jdk1.8.0_211\bin
#
# C:\Program Files (x86)\Java\jdk1.8.0_211\bin>java -jar TruthTable.jar

# %% [markdown]
# LINK: [Clique aqui!!!](https://drive.google.com/file/d/1BYawfX9gNaJSHXSUfZc03BhtF5TSuxu4/view?usp=sharing)

# %% [markdown]
# # Tópico 03 - LÓGICA PROPOSICIONAL:

# %% [markdown]
# ## Implicação Lógica: Inferência

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Implicação Lógica: MODUS PONENS

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# EXEMPLO:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Implicação Lógica: MODUS TOLLENS

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# EXEMPLO:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Equivalência Lógica:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Dupla negação:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# EXEMPLO:
# p: Hoje é quinta.
#
# ~p: Hoje NÃO é quinta.
#
# ~~p: Não é verdade que: Hoje NÃO é quinta.

# %% [markdown]
# ### Equivalência Lógica:DE MORGAN

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# EXEMPLO:
#
# p: Hoje é Quinta.
#
# q: O sol é quente.
#
# A: ~(p ^ q) <=> B: ~p v ~q portanto: A <=> B

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# EXEMPLO:
#
# p: Hoje é Quinta.
#
# q: O sol é quente.
#
# A: ~(p v q) <=> B: ~p ^ ~q portanto: A <=> B

# %% [markdown]
# <div class="hint">
#         <b>APRENDA+ :</b><br/>
#         &#10139; Site oficial <b>Python</b>:
#         <a href="https://www.python.org/">Link</a><br/>
#         &#10139; Tabela: Implicações e Equivalências Lógicas:
#         <a href="https://drive.google.com/file/d/1Ns13fcmcVJSiDD_3_wbcix2PbeuoeZgs/view?usp=sharing">Link</a><br/>
#     </div>
